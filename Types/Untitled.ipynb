# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Source
# ##### https://www.amfiindia.com/downloads
# ##### http://portal.amfiindia.com/DownloadSchemeData_Po.aspx?mf=0

# %%
df=pd.read_csv("SchemeData.csv")

# %% [markdown]
# ## Lets look at some numbers about data

# %% [markdown]
# #### Shape of Data (Rows, Columns)

# %%
df.shape
# Out:
# (18843, 9)

# %% [markdown]
# #### Size of Data Total Number of Rows and columns (Rows * Columns)

# %%
df.size
# Out:
# 169587

# %% [markdown]
# #### Dimenstion of Data (used for representation in N-Dimensional Space)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## Preview Data

# %% [markdown]
# #### First and Last Five records

# %%
df.head()
# Out:
#                                  AMC    Code  \
# 0  Aditya Birla Sun Life AMC Limited  100033
# 1  Aditya Birla Sun Life AMC Limited  100034
# 2  Aditya Birla Sun Life AMC Limited  119433
# 3  Aditya Birla Sun Life AMC Limited  119436
# 4  Aditya Birla Sun Life AMC Limited  100037
#
#                                    Scheme Name Scheme Type  \
# 0  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 1  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 2  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 3  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 4            Aditya Birla Sun Life Income Fund  Open Ended
#
#                               Scheme Category  \
# 0        Equity Scheme - Large & Mid Cap Fund
# 1        Equity Scheme - Large & Mid Cap Fund
# 2        Equity Scheme - Large & Mid Cap Fund
# 3        Equity Scheme - Large & Mid Cap Fund
# 4  Debt Scheme - Medium to Long Duration Fund
#
# ...

# %%
df.tail()
# Out:
#                                                      AMC  \
# 18838  ICICI Prudential Asset Management Company Limited
# 18839  ICICI Prudential Asset Management Company Limited
# 18840  ICICI Prudential Asset Management Company Limited
# 18841  ICICI Prudential Asset Management Company Limited
# 18842  ICICI Prudential Asset Management Company Limited
#
#                                              Scheme Name  Scheme Type  \
# 18838  ICICI Prudential Fixed Maturity Plan - Series ...  Close Ended
# 18839                          ICICI Prudential MNC Fund   Open Ended
# 18840                          ICICI Prudential MNC Fund   Open Ended
# 18841                          ICICI Prudential MNC Fund   Open Ended
# 18842                          ICICI Prudential MNC Fund   Open Ended
#
#                           Scheme Category  \
# 18838                              Income
# 18839  Equity Scheme - Sectoral/ Thematic
# 18840  Equity Scheme - Sectoral/ Thematic
# ...

# %% [markdown]
# #### First N records

# %%
df.head(7)
# Out:
#                                  AMC  \
# 0  Aditya Birla Sun Life AMC Limited
# 1  Aditya Birla Sun Life AMC Limited
# 2  Aditya Birla Sun Life AMC Limited
# 3  Aditya Birla Sun Life AMC Limited
# 4  Aditya Birla Sun Life AMC Limited
# 5  Aditya Birla Sun Life AMC Limited
# 6  Aditya Birla Sun Life AMC Limited
#
#                                    Scheme Name Scheme Type  \
# 0  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 1  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 2  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 3  Aditya Birla Sun Life Equity Advantage Fund  Open Ended
# 4            Aditya Birla Sun Life Income Fund  Open Ended
# 5            Aditya Birla Sun Life Income Fund  Open Ended
# 6            Aditya Birla Sun Life Income Fund  Open Ended
#
#                               Scheme Category  \
# 0        Equity Scheme - Large & Mid Cap Fund
# 1        Equity Scheme - Large & Mid Cap Fund
# ...

# %% [markdown]
# #### Last N records

# %%
df.tail(7)
# Out:
#                                                      AMC  \
# 18836  ICICI Prudential Asset Management Company Limited
# 18837  ICICI Prudential Asset Management Company Limited
# 18838  ICICI Prudential Asset Management Company Limited
# 18839  ICICI Prudential Asset Management Company Limited
# 18840  ICICI Prudential Asset Management Company Limited
# 18841  ICICI Prudential Asset Management Company Limited
# 18842  ICICI Prudential Asset Management Company Limited
#
#                                              Scheme Name  Scheme Type  \
# 18836  ICICI Prudential Fixed Maturity Plan - Series ...  Close Ended
# 18837  ICICI Prudential Fixed Maturity Plan - Series ...  Close Ended
# 18838  ICICI Prudential Fixed Maturity Plan - Series ...  Close Ended
# 18839                          ICICI Prudential MNC Fund   Open Ended
# 18840                          ICICI Prudential MNC Fund   Open Ended
# 18841                          ICICI Prudential MNC Fund   Open Ended
# ...

# %% [markdown]
# #### Access Range of Records
# *Ex: Access records starting from 15th record up to 20th record*

# %%
df[14:20]
# Out:
#                                   AMC                        Scheme Name  \
# 14  Aditya Birla Sun Life AMC Limited  Aditya Birla Sun Life Liquid Fund
# 15  Aditya Birla Sun Life AMC Limited  Aditya Birla Sun Life Liquid Fund
# 16  Aditya Birla Sun Life AMC Limited  Aditya Birla Sun Life Liquid Fund
# 17  Aditya Birla Sun Life AMC Limited  Aditya Birla Sun Life Liquid Fund
# 18  Aditya Birla Sun Life AMC Limited  Aditya Birla Sun Life Liquid Fund
# 19  Aditya Birla Sun Life AMC Limited  Aditya Birla Sun Life Liquid Fund
#
#    Scheme Type            Scheme Category  \
# 14  Open Ended  Debt Scheme - Liquid Fund
# 15  Open Ended  Debt Scheme - Liquid Fund
# 16  Open Ended  Debt Scheme - Liquid Fund
# 17  Open Ended  Debt Scheme - Liquid Fund
# 18  Open Ended  Debt Scheme - Liquid Fund
# 19  Open Ended  Debt Scheme - Liquid Fund
#
#                                       Scheme NAV Name Scheme Minimum Amount  \
# ...

# %%
df.describe()
# Out:
#                 Code
# count   18843.000000
# mean   131357.410763
# std     12984.539718
# min    100033.000000
# 25%    122405.500000
# 50%    134955.000000
# 75%    142137.500000
# max    147348.000000

# %%
df1= df.drop(columns=['Code'])
df1.describe()
# Out:
#                                                       AMC  \
# count                                               18843
# unique                                                 43
# top     ICICI Prudential Asset Management Company Limited
# freq                                                 2936
#
#                                        Scheme Name  Scheme Type  \
# count                                        18843        18843
# unique                                        3734            3
# top     LIC MF Unit Linked Insurance Scheme (ULIS)  Close Ended
# freq                                            36        12114
#
#        Scheme Category              Scheme NAV Name Scheme Minimum Amount  \
# count            18843                        18843                 18801
# unique              51                        18801                   392
# top             Income  Kotak Bond-Deposit-Dividend                  5000
# ...

# %%
df['Scheme Category'].unique().tolist()
# Out:
# ['Equity Scheme - Large & Mid Cap Fund',
#  'Debt Scheme - Medium to Long Duration Fund',
#  'Debt Scheme - Liquid Fund',
#  'Debt Scheme - Gilt Fund',
#  'Equity Scheme - Sectoral/ Thematic',
#  'Equity Scheme - ELSS',
#  'Debt Scheme - Medium Duration Fund',
#  'Equity Scheme - Multi Cap Fund',
#  'Hybrid Scheme - Aggressive Hybrid Fund',
#  'Debt Scheme - Money Market Fund',
#  'Hybrid Scheme - Balanced Hybrid Fund',
#  'Other Scheme - Index Funds',
#  'Debt Scheme - Dynamic Bond',
#  'Equity Scheme - Small Cap Fund',
#  'Equity Scheme - Large Cap Fund',
#  'Equity Scheme - Value Fund',
#  'Debt Scheme - Long Duration Fund',
#  'Balanced',
#  'Equity Scheme - Mid Cap Fund',
#  'Debt Scheme - Low Duration Fund',
#  'Debt Scheme - Corporate Bond Fund',
#  'Solution Oriented Scheme - Retirement Fund',
#  'Gilt',
#  'Hybrid Scheme - Conservative Hybrid Fund',
#  'Growth',
#  'Hybrid Scheme - Dynamic Asset Allocation or Balanced Advantage',
# ...
