# %%
import pandas as pd
from IPython.display import display, HTML

# %%
df = pd.read_csv('cd.csv')
df['Gross Amount paid'] = df['Gross Amount paid'] / 100
df['Gross Inflows'] = df['Gross Inflows'] / 100
df['Net Inflows'] = df['Net Inflows'] / 100
df['Average Assets under Management for FY 2018-19'] = df['Average Assets under Management for FY 2018-19'] / 100
df.shape
# Out:
# (1037, 7)

# %%
df.shape, df.dtypes
# Out:
# ((1037, 7), Sr. No.                                             int64
#  Name of the ARN Holder                             object
#  Gross Amount paid                                 float64
#  Gross Inflows                                     float64
#  Net Inflows                                       float64
#  Average Assets under Management for FY 2018-19    float64
#  Ratio of AUM to Gross inflows                      object
#  dtype: object)

# %%
df.head()
# Out:
#    Sr. No.                            Name of the ARN Holder   \
# 0        1                             3I WEALTH ADVISORS LLP
# 1        2                  6TH SENSE INVESTMENTS CONSULTANTS
# 2        3                                        A K Narayan
# 3        4  A R J Financial Consultants India Private Limited
# 4        5                            A.G. Financial Services
#
#    Gross Amount paid  Gross Inflows  Net Inflows  \
# 0             2.0662      1004.2778    -180.1647
# 1             1.0712        39.2248      11.8477
# 2             1.2903        37.3658      17.7627
# 3             1.3010        26.5618       9.5796
# 4             2.8489       105.0339     -16.0786
#
#    Average Assets under Management for FY 2018-19  \
# 0                                        322.2916
# 1                                         92.9601
# 2                                        173.0491
# 3                                         95.9208
# ...

# %%
df.describe(include=['object'])
# Out:
#        Name of the ARN Holder  Ratio of AUM to Gross inflows
# count                     1037                          1037
# unique                    1037                           485
# top        Prakash Investments                          0.03
# freq                         1                             9

# %%
df.describe(include='all')
# Out:
#             Sr. No. Name of the ARN Holder   Gross Amount paid  Gross Inflows  \
# count   1037.000000                    1037        1037.000000    1037.000000
# unique          NaN                    1037                NaN            NaN
# top             NaN     Prakash Investments                NaN            NaN
# freq            NaN                       1                NaN            NaN
# mean     519.000000                     NaN           7.655022    3751.265933
# std      299.500417                     NaN          43.169598   28892.307876
# min        1.000000                     NaN           0.123900       0.000000
# 25%      260.000000                     NaN           1.039500      44.328000
# 50%      519.000000                     NaN           1.472500      89.841400
# 75%      778.000000                     NaN           2.848900     230.939600
# max     1037.000000                     NaN         807.671900  471624.762600
#
# ...

# %%
dfg = df.sort_values(by=['Gross Amount paid'], ascending=False)

# %%
display(HTML(dfg[dfg['Gross Amount paid']>=100].to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sr. No.</th>
#       <th>Name of the ARN Holder</th>
#       <th>Gross Amount paid</th>
#       <th>Gross Inflows</th>
#       <th>Net Inflows</th>
#       <th>Average Assets under Management for FY 2018-19</th>
#       <th>Ratio of AUM to Gross inflows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>596</td>
#       <td>NJ IndiaInvest Pvt Ltd</td>
#       <td>807.6719</td>
#       <td>28356.5990</td>
#       <td>11148.7114</td>
#       <td>62946.5610</td>
#       <td>2.44</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>Axis Bank Limited</td>
#       <td>555.6306</td>
#       <td>134550.0610</td>
#       <td>755.8470</td>
#       <td>52923.0518</td>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <td>342</td>
#       <td>HDFC Bank Limited</td>
#       <td>496.6722</td>
#       <td>136790.5898</td>
#       <td>2430.5064</td>
#       <td>72943.8864</td>
# ...

# %%
display(HTML(dfg[(dfg['Gross Amount paid'] >= 50 ) & (dfg['Gross Amount paid'] < 100)].to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sr. No.</th>
#       <th>Name of the ARN Holder</th>
#       <th>Gross Amount paid</th>
#       <th>Gross Inflows</th>
#       <th>Net Inflows</th>
#       <th>Average Assets under Management for FY 2018-19</th>
#       <th>Ratio of AUM to Gross inflows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>378</td>
#       <td>Indusind Bank Ltd</td>
#       <td>94.9448</td>
#       <td>2372.3938</td>
#       <td>494.0902</td>
#       <td>6795.4176</td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>Bajaj Capital Ltd.</td>
#       <td>92.0628</td>
#       <td>6064.8387</td>
#       <td>-144.6759</td>
#       <td>10127.5061</td>
#       <td>1.69</td>
#     </tr>
#     <tr>
#       <td>433</td>
#       <td>Julius Baer Wealth Advisors (India) Private Li...</td>
#       <td>90.5635</td>
#       <td>10962.7923</td>
#       <td>161.5083</td>
# ...

# %%
display(HTML(dfg[(dfg['Gross Amount paid'] >= 25 ) & (dfg['Gross Amount paid'] < 50)].to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sr. No.</th>
#       <th>Name of the ARN Holder</th>
#       <th>Gross Amount paid</th>
#       <th>Gross Inflows</th>
#       <th>Net Inflows</th>
#       <th>Average Assets under Management for FY 2018-19</th>
#       <th>Ratio of AUM to Gross inflows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>343</td>
#       <td>HDFC Securities Ltd</td>
#       <td>48.4842</td>
#       <td>4155.8019</td>
#       <td>1532.2427</td>
#       <td>4616.2736</td>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <td>868</td>
#       <td>SPA Capital Services Limited</td>
#       <td>47.8683</td>
#       <td>95270.3195</td>
#       <td>-4211.0975</td>
#       <td>12816.6270</td>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>Canara Bank</td>
#       <td>47.6875</td>
#       <td>2640.8480</td>
#       <td>922.9780</td>
#       <td>4733.0125</td>
# ...

# %%
display(HTML(dfg[(dfg['Gross Amount paid'] >= 1 ) & (dfg['Gross Amount paid'] < 25)].to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sr. No.</th>
#       <th>Name of the ARN Holder</th>
#       <th>Gross Amount paid</th>
#       <th>Gross Inflows</th>
#       <th>Net Inflows</th>
#       <th>Average Assets under Management for FY 2018-19</th>
#       <th>Ratio of AUM to Gross inflows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>94</td>
#       <td>Ask Wealth Advisors Private Limited</td>
#       <td>24.8714</td>
#       <td>4525.6804</td>
#       <td>-356.0508</td>
#       <td>3900.0827</td>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <td>364</td>
#       <td>IIFL WEALTH ADVISORS INDIA LIMITED</td>
#       <td>22.8586</td>
#       <td>7430.8288</td>
#       <td>-621.0706</td>
#       <td>4349.9603</td>
#       <td>0.49</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>Eastern Financiers Ltd.</td>
#       <td>21.9521</td>
#       <td>1257.2115</td>
#       <td>220.4674</td>
# ...

# %%
display(HTML(dfg[(dfg['Gross Amount paid'] >= .5 ) & (dfg['Gross Amount paid'] < 1)].to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sr. No.</th>
#       <th>Name of the ARN Holder</th>
#       <th>Gross Amount paid</th>
#       <th>Gross Inflows</th>
#       <th>Net Inflows</th>
#       <th>Average Assets under Management for FY 2018-19</th>
#       <th>Ratio of AUM to Gross inflows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>313</td>
#       <td>Girish Wani</td>
#       <td>0.9974</td>
#       <td>56.3247</td>
#       <td>19.7547</td>
#       <td>94.9048</td>
#       <td>1.89</td>
#     </tr>
#     <tr>
#       <td>228</td>
#       <td>Dhanvriddhi Finvest Services Pvt Ltd</td>
#       <td>0.9934</td>
#       <td>38.8606</td>
#       <td>22.3803</td>
#       <td>140.2770</td>
#       <td>3.98</td>
#     </tr>
#     <tr>
#       <td>391</td>
#       <td>Invest Search</td>
#       <td>0.9934</td>
#       <td>53.7994</td>
#       <td>13.2655</td>
#       <td>107.8207</td>
#       <td>2.12</td>
# ...

# %%
display(HTML(dfg[(dfg['Gross Amount paid'] < .5)].to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sr. No.</th>
#       <th>Name of the ARN Holder</th>
#       <th>Gross Amount paid</th>
#       <th>Gross Inflows</th>
#       <th>Net Inflows</th>
#       <th>Average Assets under Management for FY 2018-19</th>
#       <th>Ratio of AUM to Gross inflows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>396</td>
#       <td>INVESTPRO FINANCIAL SERVICES PRIVATE LIMITED</td>
#       <td>0.4881</td>
#       <td>33.8649</td>
#       <td>12.1647</td>
#       <td>102.0758</td>
#       <td>5.46</td>
#     </tr>
#     <tr>
#       <td>601</td>
#       <td>o3 Securities Pvt Ltd</td>
#       <td>0.4656</td>
#       <td>708.7142</td>
#       <td>521.9438</td>
#       <td>125.7638</td>
#       <td>0.69</td>
#     </tr>
#     <tr>
#       <td>502</td>
#       <td>M/S ARWIND M SHAH</td>
#       <td>0.4526</td>
#       <td>47.3251</td>
#       <td>7.8744</td>
#       <td>102.0899</td>
# ...

# %%
df.sort_values(by=['Net Inflows'], ascending=False).head(10)
# Out:
#      Sr. No.                       Name of the ARN Holder   Gross Amount paid  \
# 878      879                           State Bank of India           487.5777
# 595      596                        NJ IndiaInvest Pvt Ltd           807.6719
# 875      876                      SRIVIDYA ENTERPRISES LLP             9.6270
# 681      682       Prudent Corporate Advisory Services Ltd           234.7168
# 356      357                      ICICI Securities Limited           318.8525
# 479      480                 L & T CAPITAL MARKETS LIMITED            52.4886
# 341      342                             HDFC Bank Limited           496.6722
# 352      353  Hongkong & Shanghai Banking Corporation Ltd.           113.6447
# 490      491                 LICHFL Financial Services Ltd             4.1784
# 119      120                                Bank Of Baroda            18.3534
#
#      Gross Inflows  Net Inflows  \
# 878     92081.3227   15368.2081
# 595     28356.5990   11148.7114
# ...

# %%
from IPython.display import display, HTML
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sr. No.</th>
#       <th>Name of the ARN Holder</th>
#       <th>Gross Amount paid</th>
#       <th>Gross Inflows</th>
#       <th>Net Inflows</th>
#       <th>Average Assets under Management for FY 2018-19</th>
#       <th>Ratio of AUM to Gross inflows</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3I WEALTH ADVISORS LLP</td>
#       <td>2.0662</td>
#       <td>1004.2778</td>
#       <td>-180.1647</td>
#       <td>322.2916</td>
#       <td>0.27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6TH SENSE INVESTMENTS CONSULTANTS</td>
#       <td>1.0712</td>
#       <td>39.2248</td>
#       <td>11.8477</td>
#       <td>92.9601</td>
#       <td>2.52</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>A K Narayan</td>
#       <td>1.2903</td>
#       <td>37.3658</td>
#       <td>17.7627</td>
#       <td>173.0491</td>
#       <td>4.94</td>
# ...
